# %%
#EDA NUR DEMIR- DEEP LEARNING-ASS1

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import torch
import torchvision.transforms as transforms
from torch.utils.data import Dataset, DataLoader
import PIL
import requests
from tqdm.notebook import tqdm
import numpy as np
import torch
import PIL
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print("We are using {}".format(device))
# Out:
# We are using cuda

# %% [markdown]
# ### Implement the datasets and dataloaders, visualize some data samples

# %%
from google.colab import drive
drive.mount('/content/drive')
# !unzip "/content/drive/My Drive/dl_bern/data.zip" -d "/content"
# Out:
# Görüntülenen çıkış son 5000 satıra kısaltıldı.
#   inflating: /content/chest_xray_64/train/PNEUMONIA/person598_bacteria_2454.jpeg
#   inflating: /content/chest_xray_64/train/PNEUMONIA/person552_virus_1092.jpeg
#   inflating: /content/chest_xray_64/train/PNEUMONIA/person362_virus_741.jpeg
#   inflating: /content/chest_xray_64/train/PNEUMONIA/person403_virus_803.jpeg
#   inflating: /content/chest_xray_64/train/PNEUMONIA/person1751_bacteria_4592.jpeg
#   inflating: /content/chest_xray_64/train/PNEUMONIA/person1423_bacteria_3650.jpeg
#   inflating: /content/chest_xray_64/train/PNEUMONIA/person1546_bacteria_4045.jpeg
#   inflating: /content/chest_xray_64/train/PNEUMONIA/person8_bacteria_37.jpeg
#   inflating: /content/chest_xray_64/train/PNEUMONIA/person138_virus_282.jpeg
#   inflating: /content/chest_xray_64/train/PNEUMONIA/person1063_bacteria_2997.jpeg
#   inflating: /content/chest_xray_64/train/PNEUMONIA/person287_bacteria_1355.jpeg
# ...

# %%
# !unzip -l /content/drive/My\ Drive/dl_bern/data.zip
# Out:
# Görüntülenen çıkış son 5000 satıra kısaltıldı.
#      1090  2024-03-25 15:20   chest_xray_64/train/PNEUMONIA/person362_virus_741.jpeg
#       932  2024-03-25 15:20   chest_xray_64/train/PNEUMONIA/person403_virus_803.jpeg
#      1048  2024-03-25 15:20   chest_xray_64/train/PNEUMONIA/person1751_bacteria_4592.jpeg
#      1162  2024-03-25 15:20   chest_xray_64/train/PNEUMONIA/person1423_bacteria_3650.jpeg
#      1080  2024-03-25 15:20   chest_xray_64/train/PNEUMONIA/person1546_bacteria_4045.jpeg
#      1209  2024-03-25 15:20   chest_xray_64/train/PNEUMONIA/person8_bacteria_37.jpeg
#      1031  2024-03-25 15:20   chest_xray_64/train/PNEUMONIA/person138_virus_282.jpeg
#      1080  2024-03-25 15:20   chest_xray_64/train/PNEUMONIA/person1063_bacteria_2997.jpeg
#      1082  2024-03-25 15:20   chest_xray_64/train/PNEUMONIA/person287_bacteria_1355.jpeg
#      1087  2024-03-25 15:20   chest_xray_64/train/PNEUMONIA/person360_bacteria_1647.jpeg
# ...

# %%
import os
from PIL import Image
import torchvision.transforms as transforms
from torch.utils.data import Dataset, DataLoader

# %%
import torch
import torchvision
import matplotlib.pyplot as plt
import numpy as np
from torchvision import transforms
from torchvision.datasets import ImageFolder
from torch.utils.data import DataLoader

# data trasnformation
transform = transforms.Compose([
    transforms.Grayscale(num_output_channels=1),
    transforms.Resize((224, 224)),
    transforms.ToTensor(),
])

TRAIN_DATA_PATH = "/content/chest_xray_64/train/"
train_dataset = ImageFolder(root=TRAIN_DATA_PATH, transform=transform)

# 3 samples from each class
normal_samples = [(image, label) for image, label in train_dataset if label == 0][:3]
pneumonia_samples = [(image, label) for image, label in train_dataset if label == 1][:3]

def show_images(images, title_texts):
    plt.figure(figsize=(15, 5))
    for i, (image, title) in enumerate(zip(images, title_texts)):
        plt.subplot(1, len(images), i + 1)
        plt.imshow(image.squeeze(), cmap='gray')
        plt.title(title)
        plt.axis('off')
    plt.show()

# imshow
normal_images, normal_titles = zip(*[(img, 'Normal') for img, _ in normal_samples])
pneumonia_images, pneumonia_titles = zip(*[(img, 'Pneumonia') for img, _ in pneumonia_samples])

show_images(normal_images + pneumonia_images, normal_titles + pneumonia_titles)

# %% [markdown]
# ### Implement the MLP model

# %%
import torch.nn as nn
import torch.nn.functional as F

class MLP(nn.Module):
    def __init__(self):
        super(MLP, self).__init__()
        self.fc1 = nn.Linear(224*224*1, 128)
        self.fc2 = nn.Linear(128, 128)
        self.fc3 = nn.Linear(128, 128)
        self.fc4 = nn.Linear(128, 128)
        self.fc5 = nn.Linear(128, 2)

    def forward(self, x):
        x = x.view(x.size(0), -1)
        x = F.relu(self.fc1(x))
        x = F.relu(self.fc2(x))
        x = F.relu(self.fc3(x))
        x = F.relu(self.fc4(x))
        x = self.fc5(x)
        return x

mlp_model = MLP()

# %% [markdown]
# ### Implement the CNN model

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
from torchvision import datasets, transforms
from torch.utils.data import DataLoader
import numpy as np
import matplotlib.pyplot as plt

class CNNModel(nn.Module):
    def __init__(self):
        super(CNNModel, self).__init__()
        self.conv1 = nn.Conv2d(3, 32, kernel_size=3, stride=1)
        self.pool1 = nn.MaxPool2d(kernel_size=3, stride=2, ceil_mode=True)
        self.conv2 = nn.Conv2d(32, 64, kernel_size=3, stride=1)
        self.pool2 = nn.MaxPool2d(kernel_size=3, stride=2)
        self.conv3 = nn.Conv2d(64, 64, kernel_size=3, stride=1)
        self.pool3 = nn.MaxPool2d(kernel_size=2, stride=2)
        self.conv4 = nn.Conv2d(64, 128, kernel_size=2, stride=1)
        self.conv5 = nn.Conv2d(128, 256, kernel_size=3, stride=1)
        self.conv6 = nn.Conv2d(256, 256, kernel_size=3, stride=1)
        self.conv7 = nn.Conv2d(256, 2, kernel_size=1, stride=1)
        self.global_avg_pool = nn.AdaptiveAvgPool2d((1, 1))

    def forward(self, x):
        x = F.relu(self.pool1(self.conv1(x)))
        x = F.relu(self.pool2(self.conv2(x)))
        x = F.relu(self.pool3(self.conv3(x)))
        x = F.relu(self.conv4(x))
        x = F.relu(self.conv5(x))
        x = F.relu(self.conv6(x))
        x = self.conv7(x)
        x = self.global_avg_pool(x)
        x = x.view(x.size(0), -1)
        return x

cnn_model = CNNModel()

# %% [markdown]
# ### Implement the training code

# %% [markdown]
# ### Train the MLP model

# %%
import torch
from torchvision import datasets, transforms
from torch.utils.data import DataLoader
import matplotlib.pyplot as plt
import torch.optim as optim

# I chose 224*224
transform = transforms.Compose([
    transforms.Grayscale(num_output_channels=1),
    transforms.Resize((224, 224)),
    transforms.ToTensor(),
])

# datasets
train_dataset = datasets.ImageFolder(root='/content/chest_xray_64/train/', transform=transform)
val_dataset = datasets.ImageFolder(root='/content/chest_xray_64/val/', transform=transform)

# loaders
train_loader = DataLoader(dataset=train_dataset, batch_size=32, shuffle=True)
val_loader = DataLoader(dataset=val_dataset, batch_size=32, shuffle=False)


def train_model(model, train_loader, val_loader, epochs, learning_rate):
    device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
    model.to(device)
    criterion = nn.CrossEntropyLoss()
    optimizer = optim.Adam(model.parameters(), lr=learning_rate)

    # lists to follow losses
    train_losses, val_losses, train_accuracies, val_accuracies = [], [], [], []

    for epoch in range(epochs):
        model.train()
        running_loss = 0.0
        correct_train = 0
        total_train = 0

        for images, labels in train_loader:
            images, labels = images.to(device), labels.to(device)
            optimizer.zero_grad()
            outputs = model(images)
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()
            running_loss += loss.item()
            _, predicted = torch.max(outputs, 1)
            total_train += labels.size(0)
            correct_train += (predicted == labels).sum().item()

        train_losses.append(running_loss / len(train_loader))
        train_accuracies.append(100 * correct_train / total_train)

        model.eval()
        val_loss = 0.0
        correct_val = 0
        total_val = 0
        with torch.no_grad():
            for images, labels in val_loader:
                images, labels = images.to(device), labels.to(device)
                outputs = model(images)
                loss = criterion(outputs, labels)
                val_loss += loss.item()
                _, predicted = torch.max(outputs.data, 1)
                total_val += labels.size(0)
                correct_val += (predicted == labels).sum().item()

        val_losses.append(val_loss / len(val_loader))
        val_accuracies.append(100 * correct_val / total_val)

        print(f'Epoch {epoch+1}/{epochs} - Training Loss: {train_losses[-1]:.4f}, '
              f'Validation Loss: {val_losses[-1]:.4f}, '
              f'Training Accuracy: {train_accuracies[-1]:.2f}%, '
              f'Validation Accuracy: {val_accuracies[-1]:.2f}%')

    # graphs
    plt.figure(figsize=(12, 6))
    plt.subplot(1, 2, 1)
    plt.plot(train_losses, label='Training Loss')
    plt.plot(val_losses, label='Validation Loss')
    plt.title('Loss Over Epochs')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.legend()

    plt.subplot(1, 2, 2)
    plt.plot(train_accuracies, label='Training Accuracy')
    plt.plot(val_accuracies, label='Validation Accuracy')
    plt.title('Accuracy Over Epochs')
    plt.xlabel('Epochs')
    plt.ylabel('Accuracy')
    plt.legend()
    plt.show()

train_model(mlp_model, train_loader, val_loader, epochs=30, learning_rate=1e-3)
# Out:
# Epoch 1/30 - Training Loss: 0.1412, Validation Loss: 1.5453, Training Accuracy: 94.75%, Validation Accuracy: 68.91%
# Epoch 2/30 - Training Loss: 0.1400, Validation Loss: 0.9041, Training Accuracy: 94.63%, Validation Accuracy: 77.56%
# Epoch 3/30 - Training Loss: 0.1299, Validation Loss: 0.9654, Training Accuracy: 95.07%, Validation Accuracy: 71.79%
# Epoch 4/30 - Training Loss: 0.1340, Validation Loss: 1.1129, Training Accuracy: 94.86%, Validation Accuracy: 69.39%
# Epoch 5/30 - Training Loss: 0.1310, Validation Loss: 0.8070, Training Accuracy: 95.02%, Validation Accuracy: 75.00%
# Epoch 6/30 - Training Loss: 0.1220, Validation Loss: 0.7496, Training Accuracy: 95.40%, Validation Accuracy: 76.60%
# Epoch 7/30 - Training Loss: 0.1063, Validation Loss: 1.1244, Training Accuracy: 95.99%, Validation Accuracy: 72.92%
# Epoch 8/30 - Training Loss: 0.1228, Validation Loss: 1.2963, Training Accuracy: 95.38%, Validation Accuracy: 69.87%
# ...

# %% [markdown]
# ### Train the CNN model

# %%
import numpy as np
import torch
from torchvision import datasets, transforms
from torch.utils.data import DataLoader

# I chose 224*224
transform = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.ToTensor(),
])

train_dataset = datasets.ImageFolder(root='/content/chest_xray_64/train/', transform=transform)
val_dataset = datasets.ImageFolder(root='/content/chest_xray_64/val/', transform=transform)

train_loader = DataLoader(dataset=train_dataset, batch_size=32, shuffle=True, num_workers=4)
val_loader = DataLoader(dataset=val_dataset, batch_size=32, shuffle=False, num_workers=4)
import torch
import numpy as np

def train_epoch(model, dataloader, optimizer, loss_fn, device):
    model.train()
    losses = []
    correct_predictions = 0
    total_predictions = 0

    for images, labels in dataloader:
        images, labels = images.to(device), labels.to(device)
        optimizer.zero_grad()
        outputs = model(images)
        loss = loss_fn(outputs, labels)
        loss.backward()
        optimizer.step()

        losses.append(loss.item())
        _, predicted_labels = torch.max(outputs, 1)
        correct_predictions += (predicted_labels == labels).sum().item()
        total_predictions += labels.size(0)

    accuracy = 100.0 * correct_predictions / total_predictions
    return np.mean(losses), accuracy

def evaluate(model, dataloader, loss_fn, device):
    model.eval()
    losses = []
    correct_predictions = 0
    total_predictions = 0

    with torch.no_grad():
        for images, labels in dataloader:
            images, labels = images.to(device), labels.to(device)
            outputs = model(images)
            loss = loss_fn(outputs, labels)
            losses.append(loss.item())
            _, predicted_labels = torch.max(outputs, 1)
            correct_predictions += (predicted_labels == labels).sum().item()
            total_predictions += labels.size(0)

    accuracy = 100.0 * correct_predictions / total_predictions
    return np.mean(losses), accuracy

def train(model, train_dataloader, val_dataloader, optimizer, n_epochs, loss_fn, device):
    train_losses, val_losses, train_accuracies, val_accuracies = [], [], [], []

    for epoch in range(n_epochs):
        train_loss, train_accuracy = train_epoch(model, train_dataloader, optimizer, loss_fn, device)
        val_loss, val_accuracy = evaluate(model, val_dataloader, loss_fn, device)

        train_losses.append(train_loss)
        val_losses.append(val_loss)
        train_accuracies.append(train_accuracy)
        val_accuracies.append(val_accuracy)

        print(f'Epoch {epoch+1}/{n_epochs}: train_loss: {train_loss:.4f}, train_accuracy: {train_accuracy:.4f}%, val_loss: {val_loss:.4f}, val_accuracy: {val_accuracy:.4f}%')

    return train_losses, val_losses, train_accuracies, val_accuracies

# %%
import matplotlib.pyplot as plt

def plot(n_epochs, train_losses, val_losses, train_accuracies, val_accuracies):
    plt.figure(figsize=(10, 5))
    plt.subplot(1, 2, 1)
    plt.plot(range(n_epochs), train_losses, label='Train Loss')
    plt.plot(range(n_epochs), val_losses, label='Validation Loss')
    plt.title('Training and Validation Loss')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.legend()

    plt.subplot(1, 2, 2)
    plt.plot(range(n_epochs), train_accuracies, label='Train Accuracy')
    plt.plot(range(n_epochs), val_accuracies, label='Validation Accuracy')
    plt.title('Training and Validation Accuracy')
    plt.xlabel('Epochs')
    plt.ylabel('Accuracy')
    plt.legend()
    plt.tight_layout()
    plt.show()

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

model = CNNModel().to(device)
loss_fn = torch.nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model.parameters(), lr=0.001)
n_epochs = 30

train_losses, val_losses, train_acc, val_acc = train(model, train_loader, val_loader, optimizer, n_epochs, loss_fn, device)

plot(n_epochs, train_losses, val_losses, train_acc, val_acc)
# Out:
# /usr/lib/python3.10/multiprocessing/popen_fork.py:66: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   self.pid = os.fork()
# /usr/lib/python3.10/multiprocessing/popen_fork.py:66: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   self.pid = os.fork()
# Epoch 1/30: train_loss: 0.5779, train_accuracy: 74.2906%, val_loss: 0.6860, val_accuracy: 62.5000%
# Epoch 2/30: train_loss: 0.5740, train_accuracy: 74.2906%, val_loss: 0.6738, val_accuracy: 62.5000%
# Epoch 3/30: train_loss: 0.5476, train_accuracy: 74.5590%, val_loss: 0.7120, val_accuracy: 64.2628%
# Epoch 4/30: train_loss: 0.3419, train_accuracy: 84.7201%, val_loss: 0.5897, val_accuracy: 70.1923%
# Epoch 5/30: train_loss: 0.1945, train_accuracy: 92.4463%, val_loss: 0.5455, val_accuracy: 78.8462%
# ...

# %% [markdown]
# ## Implement  regularization techniques

# %% [markdown]
# ## First technique

# %%
def train_l1(model, train_dataloader, val_dataloader, optimizer, n_epochs, loss_fn, device, lambda_l1):
    train_losses, val_losses, train_accuracies, val_accuracies = [], [], [], []

    for epoch in range(n_epochs):
        model.train()
        train_loss = 0
        train_l1_reg_loss = 0
        correct_predictions = 0
        total_predictions = 0

        for images, labels in train_dataloader:
            images, labels = images.to(device), labels.to(device)
            optimizer.zero_grad()
            outputs = model(images)
            loss = loss_fn(outputs, labels)

            l1_reg = torch.tensor(0.).to(device)
            for param in model.parameters():
                l1_reg += torch.norm(param, 1)
            total_loss = loss + lambda_l1 * l1_reg

            total_loss.backward()
            optimizer.step()

            train_loss += loss.item()
            train_l1_reg_loss += (lambda_l1 * l1_reg).item()
            _, predicted_labels = torch.max(outputs, 1)
            correct_predictions += (predicted_labels == labels).sum().item()
            total_predictions += labels.size(0)

        train_losses.append(train_loss / len(train_dataloader))
        train_accuracies.append(correct_predictions / total_predictions * 100)

        val_loss, val_accuracy = evaluate(model, val_dataloader, loss_fn, device)
        val_losses.append(val_loss)
        val_accuracies.append(val_accuracy)

        print(f'Epoch {epoch+1}/{n_epochs}: train_loss: {train_losses[-1]:.4f}, train_l1_reg_loss: {train_l1_reg_loss / len(train_dataloader):.4f}, train_accuracy: {train_accuracies[-1]:.4f}%, val_loss: {val_losses[-1]:.4f}, val_accuracy: {val_accuracies[-1]:.4f}%')

    return train_losses, val_losses, train_accuracies, val_accuracies

lambda_l1 = 1e-5
optimizer = torch.optim.Adam(model.parameters(), lr=0.001)
train_losses, val_losses, train_acc, val_acc = train_l1(model, train_loader, val_loader, optimizer, n_epochs, loss_fn, device, lambda_l1)
plot(n_epochs, train_losses, val_losses, train_acc, val_acc)
# Out:
# Epoch 1/30: train_loss: 0.0132, train_l1_reg_loss: 0.1281, train_accuracy: 99.5207%, val_loss: 1.7058, val_accuracy: 78.5256%
# Epoch 2/30: train_loss: 0.0097, train_l1_reg_loss: 0.1133, train_accuracy: 99.6741%, val_loss: 1.5891, val_accuracy: 79.6474%
# Epoch 3/30: train_loss: 0.0143, train_l1_reg_loss: 0.1110, train_accuracy: 99.4440%, val_loss: 2.2321, val_accuracy: 73.0769%
# Epoch 4/30: train_loss: 0.0085, train_l1_reg_loss: 0.1059, train_accuracy: 99.7891%, val_loss: 1.6631, val_accuracy: 79.6474%
# Epoch 5/30: train_loss: 0.0127, train_l1_reg_loss: 0.0992, train_accuracy: 99.4632%, val_loss: 1.5388, val_accuracy: 78.2051%
# Epoch 6/30: train_loss: 0.0217, train_l1_reg_loss: 0.1005, train_accuracy: 99.0989%, val_loss: 1.1586, val_accuracy: 80.7692%
# Epoch 7/30: train_loss: 0.0033, train_l1_reg_loss: 0.0929, train_accuracy: 100.0000%, val_loss: 1.3147, val_accuracy: 80.9295%
# ...

# %% [markdown]
# ## Second technique

# %%
def train_l2(model, train_loader, val_loader, optimizer, n_epochs, loss_fn, device):
    train_losses, val_losses, train_accuracies, val_accuracies = [], [], [], []
    for epoch in range(n_epochs):
        model.train()
        running_loss = 0.0
        correct = 0
        total = 0
        for inputs, targets in train_loader:
            inputs, targets = inputs.to(device), targets.to(device)
            optimizer.zero_grad()
            outputs = model(inputs)
            loss = loss_fn(outputs, targets)
            loss.backward()
            optimizer.step()
            running_loss += loss.item()
            _, predicted = torch.max(outputs.data, 1)
            total += targets.size(0)
            correct += (predicted == targets).sum().item()
        epoch_loss = running_loss / len(train_loader)
        epoch_acc = 100 * correct / total
        train_losses.append(epoch_loss)
        train_accuracies.append(epoch_acc)

        val_loss, val_acc = evaluate(model, val_loader, loss_fn, device)
        val_losses.append(val_loss)
        val_accuracies.append(val_acc)

        print(f'Epoch {epoch+1}/{n_epochs}: Train Loss: {epoch_loss:.4f}, Train Accuracy: {epoch_acc:.2f}%, Val Loss: {val_loss:.4f}, Val Accuracy: {val_acc:.2f}%')

    return train_losses, val_losses, train_accuracies, val_accuracies

weight_decay = 1e-5
optimizer_l2 = torch.optim.Adam(model.parameters(), lr=0.001, weight_decay=weight_decay)

model.to(device)
n_epochs = 30
loss_fn = nn.CrossEntropyLoss()

train_losses_l2, val_losses_l2, train_accuracies_l2, val_accuracies_l2 = train_l2(model, train_loader, val_loader, optimizer_l2, n_epochs, loss_fn, device)

plot(n_epochs, train_losses_l2, val_losses_l2, train_accuracies_l2, val_accuracies_l2)
# Out:
# Epoch 1/30: Train Loss: 0.0143, Train Accuracy: 99.48%, Val Loss: 1.4484, Val Accuracy: 81.41%
# Epoch 2/30: Train Loss: 0.0302, Train Accuracy: 99.04%, Val Loss: 0.8707, Val Accuracy: 82.69%
# Epoch 3/30: Train Loss: 0.0133, Train Accuracy: 99.54%, Val Loss: 1.3491, Val Accuracy: 79.65%
# Epoch 4/30: Train Loss: 0.0042, Train Accuracy: 99.90%, Val Loss: 1.8006, Val Accuracy: 77.40%
# Epoch 5/30: Train Loss: 0.0022, Train Accuracy: 99.98%, Val Loss: 2.0085, Val Accuracy: 78.69%
# Epoch 6/30: Train Loss: 0.0029, Train Accuracy: 99.94%, Val Loss: 1.6651, Val Accuracy: 82.21%
# Epoch 7/30: Train Loss: 0.0718, Train Accuracy: 97.49%, Val Loss: 1.1413, Val Accuracy: 78.53%
# Epoch 8/30: Train Loss: 0.0118, Train Accuracy: 99.62%, Val Loss: 1.5848, Val Accuracy: 78.37%
# Epoch 9/30: Train Loss: 0.0039, Train Accuracy: 99.88%, Val Loss: 1.9232, Val Accuracy: 78.53%
# Epoch 10/30: Train Loss: 0.0064, Train Accuracy: 99.77%, Val Loss: 2.0099, Val Accuracy: 77.72%
# ...

# %% [markdown]
# # Results comparison - Summary

# %% [markdown]
# **ANSWERS:**
# Validation Accuracy of MLP MODEL: 77.24%
# Validation Accuracy of CNN MODEL: 78.8462%
# Validation Accuracy With l1 regularization: 81.0897%
# Validation Accuracy With l2 regularization: 79.97%

# %% [markdown]
# 1) The model with L1 regularization achieved the highest validation accuracy. This is because of L1's ability to simplify the model since it drives less important weights towards zero which basically means promoting sparsity.
#
# 2) To improve accuracy, enhancements such as advanced data augmentation, incorporation of dropout layers and maybe finding different model architectures could be implemented. Furthermore, increasing the size of the training dataset could be beneficial.
#
# 3) The performance of other models are not the best because because they lacked sufficient regularization. So they lead to overfitting. MLP may not captured the spatial hierarchies in image data as good as the CNNs. Therefore,  it resulted in lower validation accuracy.
